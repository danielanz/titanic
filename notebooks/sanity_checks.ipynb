# %%
import sys
from pathlib import Path

# Add project root to Python path
project_root = Path.cwd().parent
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from src.models.pipelines import *

# %%
train = pd.read_parquet(Path.cwd().parent / 'input' / 'features' / 'train_features.parquet')
test = pd.read_parquet(Path.cwd().parent / 'input' / 'features' / 'test_features.parquet')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Survived            891 non-null    int64
#  1   Pclass              891 non-null    int64
#  2   Sex                 891 non-null    object
#  3   Age                 714 non-null    float64
#  4   Embarked            889 non-null    object
#  5   Title               891 non-null    object
#  6   has_cabin           891 non-null    int64
#  7   is_female_or_child  891 non-null    int64
#  8   family_size         891 non-null    int64
#  9   is_alone            891 non-null    int64
#  10  sex_pclass          891 non-null    object
#  11  fare_per_person     891 non-null    float64
# dtypes: float64(2), int64(6), object(4)
# memory usage: 83.7+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Pclass              418 non-null    int64
#  1   Sex                 418 non-null    object
#  2   Age                 332 non-null    float64
#  3   Embarked            418 non-null    object
#  4   Title               418 non-null    object
#  5   has_cabin           418 non-null    int64
#  6   is_female_or_child  418 non-null    int64
#  7   family_size         418 non-null    int64
#  8   is_alone            418 non-null    int64
#  9   sex_pclass          418 non-null    object
#  10  fare_per_person     417 non-null    float64
# dtypes: float64(2), int64(5), object(4)
# memory usage: 36.1+ KB

# %%
pipe = lr_pipeline

# %%
# Check Age imputation
age_imp = pipe.named_steps['age_imputer']
age_imp.fit(train)
train_imputed = age_imp.transform(train)
train_imputed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Survived            891 non-null    int64
#  1   Pclass              891 non-null    int64
#  2   Sex                 891 non-null    object
#  3   Age                 891 non-null    float64
#  4   Embarked            889 non-null    object
#  5   Title               891 non-null    object
#  6   has_cabin           891 non-null    int64
#  7   is_female_or_child  891 non-null    int64
#  8   family_size         891 non-null    int64
#  9   is_alone            891 non-null    int64
#  10  sex_pclass          891 non-null    object
#  11  fare_per_person     891 non-null    float64
# dtypes: float64(2), int64(6), object(4)
# memory usage: 83.7+ KB

# %%
train['Title'].value_counts()
# Out:
# Title
# Mr          517
# Miss        182
# Mrs         125
# Master       40
# Dr            7
# Rev           6
# Mlle          2
# Major         2
# Col           2
# Countess      1
# Capt          1
# Ms            1
# Sir           1
# Lady          1
# Mme           1
# Don           1
# Jonkheer      1
# Name: count, dtype: int64

# %%
# Check Rare Title grouping
rare_title = pipe.named_steps['rare_title']
rare_title.fit(train)
train_grouped = rare_title.transform(train)
train_grouped['Title'].value_counts()
# Out:
# Title
# Mr        517
# Miss      182
# Mrs       125
# Master     40
# Other      27
# Name: count, dtype: int64

# %%
# Check preprocessor
preprocessor = pipe.named_steps['preprocessor']
preprocessor.fit(train)
train_preprocessed = preprocessor.transform(train)
train_preprocessed
# Out:
# array([[-0.56573646,  0.05915988, -1.20571261, ...,  0.        ,
#          0.        ,  1.        ],
#        [ 0.66386103,  0.05915988,  1.20878992, ...,  0.        ,
#          0.        ,  0.        ],
#        [-0.25833709, -0.56097483, -0.43881958, ...,  0.        ,
#          0.        ,  0.        ],
#        ...,
#        [-0.1046374 ,  1.29942929, -0.74538143, ...,  0.        ,
#          0.        ,  0.        ],
#        [-0.25833709, -0.56097483,  1.01373794, ...,  1.        ,
#          0.        ,  0.        ],
#        [ 0.20276197, -0.56097483, -0.46192113, ...,  0.        ,
#          0.        ,  1.        ]], shape=(891, 37))
